# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarTrejoh/reportes_ejemplos/blob/main/05_Cartera_Cr%C3%A9dito_Vivienda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis del Saldo de Cartera: Créditos a la Vivienda
#
#
# *   Entidades Financieras de Banca Múliple
# *   Fuente: Portafolio de Información ABM / Boletínes Estadísticos
#
#
# *Periodo de Información: Enero 2017 - Julio 2023*

# %% [markdown]
# ## Importar Librerías
#
#
#
# *   Importar librerías requeridas
# *   Cargar la base de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
# %matplotlib inline

# %%
url = 'https://bit.ly/cartera_vivienda'

# %% [markdown]
# ## Limpieza DataFrame: IMOR

# %%
df1 = pd.read_excel(url, sheet_name='Acumulado')
df2 = pd.read_excel(url, sheet_name='IMOR', dtype=str)

# %%
df2.head()
# Out:
#        Entidad 2017-01-31 00:00:00 2017-02-28 00:00:00 2017-03-31 00:00:00  \
# 0   Sistema */            2.768919            2.639397            2.576646
# 1  BBVA México            4.037365            3.956234            3.888898
# 2    Santander            4.225893            3.665412            3.522557
# 3      Banamex            0.875854            0.854364            0.934583
# 4      Banorte            0.893203            0.880329            0.846795
#
#   2017-04-30 00:00:00 2017-05-31 00:00:00 2017-06-30 00:00:00  \
# 0            2.602742             2.63175            2.646513
# 1            3.956812            3.883522            3.825838
# 2            3.515537            3.638968            3.751485
# 3            0.927705            0.998318            0.948985
# 4            0.906038            0.913917            0.926476
#
#   2017-07-31 00:00:00 2017-08-31 00:00:00 2017-09-30 00:00:00  ...  \
# 0            2.672867            2.697593            2.616595  ...
# ...

# %%
df3 = df2.copy()

# %%
df3
# Out:
#                   Entidad 2017-01-31 00:00:00 2017-02-28 00:00:00  \
# 0              Sistema */            2.768919            2.639397
# 1             BBVA México            4.037365            3.956234
# 2               Santander            4.225893            3.665412
# 3                 Banamex            0.875854            0.854364
# 4                 Banorte            0.893203            0.880329
# 5                    HSBC            1.347286            1.370526
# 6              Scotiabank            2.462479              2.4313
# 7                 Inbursa            5.325677            5.790225
# 8         Bank of America                   0                   0
# 9         Banco del Bajío            5.565615              5.5091
# 10                 Afirme            2.975159            3.078981
# 11           Banco Azteca            5.085928            5.242967
# 12            J.P. Morgan                   0                   0
# ...

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=53, step=1)

# %%
df3.columns
# Out:
# Index([          'Entidad', 2017-01-31 00:00:00, 2017-02-28 00:00:00,
#        2017-03-31 00:00:00, 2017-04-30 00:00:00, 2017-05-31 00:00:00,
#        2017-06-30 00:00:00, 2017-07-31 00:00:00, 2017-08-31 00:00:00,
#        2017-09-30 00:00:00, 2017-10-31 00:00:00, 2017-11-30 00:00:00,
#        2017-12-31 00:00:00, 2018-01-31 00:00:00, 2018-02-28 00:00:00,
#        2018-03-31 00:00:00, 2018-04-30 00:00:00, 2018-05-31 00:00:00,
#        2018-06-30 00:00:00, 2018-07-31 00:00:00, 2018-08-31 00:00:00,
#        2018-09-30 00:00:00, 2018-10-31 00:00:00, 2018-11-30 00:00:00,
#        2018-12-31 00:00:00, 2019-01-31 00:00:00, 2019-02-28 00:00:00,
#        2019-03-31 00:00:00, 2019-04-30 00:00:00, 2019-05-31 00:00:00,
#        2019-06-30 00:00:00, 2019-07-31 00:00:00, 2019-08-31 00:00:00,
#        2019-09-30 00:00:00, 2019-10-31 00:00:00, 2019-11-30 00:00:00,
#        2019-12-31 00:00:00, 2020-01-31 00:00:00, 2020-02-29 00:00:00,
# ...

# %%
#df3 = df3.rename(columns={'Unnamed: 0': 'Entidad'})

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.shape
# Out:
# (53, 80)

# %%
df3.size
# Out:
# 4240

# %%
df3 = df3.replace({"#N/D": 0, "n. a.":0, "n.a.":0, "n.d.":0,
                   'n. d.':0, 'n.a':0})

# %%
df3.set_index('Entidad', inplace=True)

# %%
df3
# Out:
#                       2017-01-31 2017-02-28 2017-03-31 2017-04-30 2017-05-31  \
# Entidad
# Sistema */              2.768919   2.639397   2.576646   2.602742    2.63175
# BBVA México             4.037365   3.956234   3.888898   3.956812   3.883522
# Santander               4.225893   3.665412   3.522557   3.515537   3.638968
# Banamex                 0.875854   0.854364   0.934583   0.927705   0.998318
# Banorte                 0.893203   0.880329   0.846795   0.906038   0.913917
# HSBC                    1.347286   1.370526   1.317164   1.268309   1.297941
# Scotiabank              2.462479     2.4313   2.327379   2.320025   2.336694
# Inbursa                 5.325677   5.790225    6.01069   6.141387   6.719478
# Bank of America                0          0          0          0          0
# Banco del Bajío         5.565615     5.5091   5.350039   4.970466   5.389802
# Afirme                  2.975159   3.078981   2.916698    2.82474   3.128152
# ...

# %%
df4 = df3.transpose()

# %%
df4.reset_index(inplace=True)

# %%
df4 = df4.set_index('index')

# %%
df4
# Out:
# Entidad           Sistema */       BBVA México         Santander  \
# index
# 2017-01-31          2.768919          4.037365          4.225893
# 2017-02-28          2.639397          3.956234          3.665412
# 2017-03-31          2.576646          3.888898          3.522557
# 2017-04-30          2.602742          3.956812          3.515537
# 2017-05-31           2.63175          3.883522          3.638968
# ...                      ...               ...               ...
# 2023-03-31  2.55460935433633  1.92513082336489   2.9438880461435
# 2023-04-30   2.5470964721956    1.790722443523  2.96637629782256
# 2023-05-31  2.60002045083392  1.89379297771078  3.06235771516787
# 2023-06-30  2.60118476138102  1.87580488625561  3.09113655533489
# 2023-07-31  2.60922199055104  1.89137989259727  3.15572777395562
#
# Entidad              Banamex            Banorte              HSBC  \
# index
# 2017-01-31          0.875854           0.893203          1.347286
# ...

# %%
df4.columns
# Out:
# Index(['Sistema */', 'BBVA México', 'Santander', 'Banamex', 'Banorte', 'HSBC',
#        'Scotiabank', 'Inbursa', 'Bank of America', 'Banco del Bajío', 'Afirme',
#        'Banco Azteca', 'J.P. Morgan', 'Monex', 'Banregio', 'Invex', 'Multiva',
#        'Barclays', 'Banca Mifel', 'Ve por Más', 'CIBanco', 'Deutsche Bank',
#        'Compartamos', 'Bansí', 'Banco Base', 'Actinver', 'American Express',
#        'Consubanco', 'Sabadell', 'Volkswagen Bank', 'ABC Capital',
#        'Inmobiliario Mexicano', 'Autofin', 'Bankaool', 'ICBC', 'Forjadores',
#        'Dondé Banco', 'BNP Paribas México', 'Mizuho Bank', 'American Express',
#        'Bank of China', 'Bankaool', 'ICBC', 'KEB Hana México', 'Banco S3',
#        'Shinhan', 'Banco Covalto', 'ABC Capital', 'Volkswagen Bank',
#        'Deutsche Bank', 'Forjadores', 'Dondé Banco', 'Pagatodo'],
#       dtype='object', name='Entidad')

# %%
df4 = df4.rename(columns={'Sistema */': 'Sistema'})

# %%
df4.describe()
# Out:
# Entidad   Sistema BBVA México Santander   Banamex   Banorte      HSBC  \
# count          79          79        79        79        79        79
# unique         79          79        79        79        79        79
# top      2.768919    4.037365  4.225893  0.875854  0.893203  1.347286
# freq            1           1         1         1         1         1
#
# Entidad Scotiabank   Inbursa Bank of America Banco del Bajío  ...  \
# count           79        79              79              79  ...
# unique          79        79               2              79  ...
# top       2.462479  5.325677               0        5.565615  ...
# freq             1         1              60               1  ...
#
# Entidad KEB Hana México Banco S3 Shinhan Banco Covalto ABC Capital  \
# count                66       66      66            66          66
# unique                2        2       2             1           2
# top                   0        0       0             0           0
# ...

# %%
df4.index
# Out:
# DatetimeIndex(['2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31',
#                '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
#                '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31',
#                '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31',
#                '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31',
#                '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 79 entries, 2017-01-31 to 2023-07-31
# Data columns (total 53 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sistema                79 non-null     object
#  1   BBVA México            79 non-null     object
#  2   Santander              79 non-null     object
#  3   Banamex                79 non-null     object
#  4   Banorte                79 non-null     object
#  5   HSBC                   79 non-null     object
#  6   Scotiabank             79 non-null     object
#  7   Inbursa                79 non-null     object
#  8   Bank of America        79 non-null     object
#  9   Banco del Bajío        79 non-null     object
#  10  Afirme                 79 non-null     object
#  11  Banco Azteca           79 non-null     object
#  12  J.P. Morgan            79 non-null     object
#  13  Monex                  79 non-null     object
# ...

# %%
for column in df4:
  df4[column]= df4[column].astype('float')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 79 entries, 2017-01-31 to 2023-07-31
# Data columns (total 53 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sistema                79 non-null     float64
#  1   BBVA México            79 non-null     float64
#  2   Santander              79 non-null     float64
#  3   Banamex                79 non-null     float64
#  4   Banorte                79 non-null     float64
#  5   HSBC                   79 non-null     float64
#  6   Scotiabank             79 non-null     float64
#  7   Inbursa                79 non-null     float64
#  8   Bank of America        79 non-null     float64
#  9   Banco del Bajío        79 non-null     float64
#  10  Afirme                 79 non-null     float64
#  11  Banco Azteca           79 non-null     float64
#  12  J.P. Morgan            79 non-null     float64
#  13  Monex                  79 non-null     float64
# ...

# %%
df4
# Out:
# Entidad      Sistema  BBVA México  Santander   Banamex   Banorte      HSBC  \
# index
# 2017-01-31  2.768919     4.037365   4.225893  0.875854  0.893203  1.347286
# 2017-02-28  2.639397     3.956234   3.665412  0.854364  0.880329  1.370526
# 2017-03-31  2.576646     3.888898   3.522557  0.934583  0.846795  1.317164
# 2017-04-30  2.602742     3.956812   3.515537  0.927705  0.906038  1.268309
# 2017-05-31  2.631750     3.883522   3.638968  0.998318  0.913917  1.297941
# ...              ...          ...        ...       ...       ...       ...
# 2023-03-31  2.554609     1.925131   2.943888  3.325291  0.845165  2.294425
# 2023-04-30  2.547096     1.790722   2.966376  3.355768  0.863644  2.291253
# 2023-05-31  2.600020     1.893793   3.062358  3.445418  0.842448  2.289732
# 2023-06-30  2.601185     1.875805   3.091137  3.495969  0.843561  2.181817
# 2023-07-31  2.609222     1.891380   3.155728  3.458069  0.812953  2.203937
#
# ...

# %%
df4.describe()
# Out:
# Entidad    Sistema  BBVA México  Santander    Banamex    Banorte       HSBC  \
# count    79.000000    79.000000  79.000000  79.000000  79.000000  79.000000
# mean      2.895707     2.977839   4.098115   2.445914   0.969750   2.092416
# std       0.321299     0.554977   0.538962   1.123993   0.114527   0.787203
# min       2.547096     1.790722   2.943888   0.827400   0.812953   0.933644
# 25%       2.637414     2.606535   3.766453   1.137478   0.885610   1.267914
# 50%       2.768072     3.049656   4.203348   3.208742   0.932157   2.268639
# 75%       3.143105     3.362275   4.468489   3.415658   1.033491   2.797028
# max       3.639796     4.037365   4.945360   3.858713   1.346531   3.393057
#
# Entidad  Scotiabank    Inbursa  Bank of America  Banco del Bajío  ...  \
# count     79.000000  79.000000             79.0        79.000000  ...
# mean       3.282851  14.019960              0.0         4.971351  ...
# std        0.810476   4.888299              0.0         0.712132  ...
# ...

# %%
maxSistema = df4['Sistema'].max()
minSistema = df4['Sistema'].min()

# %%
(minSistema, maxSistema)
# Out:
# (2.5470964721956, 3.639796)

# %%
df4 = df4.rename(columns={'index': 'Periodo'})

# %%
df4
# Out:
# Entidad      Sistema  BBVA México  Santander   Banamex   Banorte      HSBC  \
# index
# 2017-01-31  2.768919     4.037365   4.225893  0.875854  0.893203  1.347286
# 2017-02-28  2.639397     3.956234   3.665412  0.854364  0.880329  1.370526
# 2017-03-31  2.576646     3.888898   3.522557  0.934583  0.846795  1.317164
# 2017-04-30  2.602742     3.956812   3.515537  0.927705  0.906038  1.268309
# 2017-05-31  2.631750     3.883522   3.638968  0.998318  0.913917  1.297941
# ...              ...          ...        ...       ...       ...       ...
# 2023-03-31  2.554609     1.925131   2.943888  3.325291  0.845165  2.294425
# 2023-04-30  2.547096     1.790722   2.966376  3.355768  0.863644  2.291253
# 2023-05-31  2.600020     1.893793   3.062358  3.445418  0.842448  2.289732
# 2023-06-30  2.601185     1.875805   3.091137  3.495969  0.843561  2.181817
# 2023-07-31  2.609222     1.891380   3.155728  3.458069  0.812953  2.203937
#
# ...

# %% [markdown]
# ## Visualización IMOR

# %%
fig, ax=plt.subplots(figsize=(9,5), layout='constrained')
#style.use('ggplot')

df4['Sistema'].plot(ax=ax, linestyle= '-', color= 'red', linewidth='2')
df4[['BBVA México','Banorte','Santander','Scotiabank','HSBC','Banamex']].plot(ax=ax, linestyle= '--', linewidth='1.2', alpha=0.8)

ax.set_title('IMOR: Cartera de Créditos a la Vivienda  \n Información al mes de Julio 2023',fontsize= 12, color='blue')

ax.set_xlabel('Periodo', fontsize= 8, color='black')

ax.tick_params(labelsize='medium', width=3)
ax.set_ylabel('IMOR (%)', fontsize= 8, color='black')
ax.legend(loc="upper right", fontsize=7)

ax.grid(alpha=0.2, color ='g')

plt.yticks(fontsize=7)

plt.show()

# %% [markdown]
# ## Limpieza DataFrame: Salo de Cartera

# %%
df1
# Out:
#                   Entidad  2018-01-01 00:00:00  2018-02-01 00:00:00  \
# 0              Sistema */        749675.723800        753802.232500
# 1            BBVA MÃ©xico        197142.792000        199329.963100
# 2               Santander        130563.864800        130943.306500
# 3                 Banamex         85601.395290         84613.974660
# 4                 Banorte        137653.159900        139185.852300
# 5                    HSBC         38862.208430         39334.418980
# 6              Scotiabank        107742.170400        108616.734500
# 7                 Inbursa          6808.237588          6779.503969
# 8        Banco del BajÃ­o          6911.384091          6869.211957
# 9             J.P. Morgan             0.000000             0.000000
# 10           Banco Azteca           377.947302           372.098546
# 11                 Afirme          5892.721487          6021.953176
# 12        Bank of America             0.000000             0.000000
# ...

# %%
df1 = df1.replace({"#N/D": 0, "n. a.":0, "n.a.":0, "n.d.":0,
                   'n. d.':0, 'n.a':0, '-': 0})

# %%
df1.set_index('Entidad', inplace=True)

# %%
df1 = df1.transpose()

# %%
df1.reset_index(inplace=True)

# %%
df1 = df1.set_index('index')

# %%
df1 = df1.rename(columns={'Sistema */': 'Sistema', 'BBVA MÃ©xico': 'BBVA México', "DondÃ© Banco":"Dondé Banco"})

# %%
for column in df1:
  df1[column]= df1[column].astype('float')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 66 entries, 2018-01-01 to 2023-06-01
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sistema                66 non-null     float64
#  1   BBVA México            66 non-null     float64
#  2   Santander              66 non-null     float64
#  3   Banamex                66 non-null     float64
#  4   Banorte                66 non-null     float64
#  5   HSBC                   66 non-null     float64
#  6   Scotiabank             66 non-null     float64
#  7   Inbursa                66 non-null     float64
#  8   Banco del BajÃ­o       66 non-null     float64
#  9   J.P. Morgan            66 non-null     float64
#  10  Banco Azteca           66 non-null     float64
#  11  Afirme                 66 non-null     float64
#  12  Bank of America        66 non-null     float64
#  13  Banregio               66 non-null     float64
# ...

# %%
df1.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
# ...

# %%
df1.describe()
# Out:
# Entidad       Sistema    BBVA México      Santander       Banamex  \
# count    6.600000e+01      66.000000      66.000000     66.000000
# mean     9.860211e+05  254608.855111  170160.338208  78519.134142
# std      1.534520e+05   37673.189122   27627.931746   6692.657712
# min      7.496757e+05  197142.792000  130563.864800  68202.114630
# 25%      8.568158e+05  222626.146900  144910.271700  70985.182318
# 50%      9.737477e+05  252989.208600  165986.585450  81228.545670
# 75%      1.104448e+06  283203.757925  195358.523550  84354.412905
# max      1.272392e+06  322650.085000  214844.677000  87034.291220
#
# Entidad        Banorte           HSBC     Scotiabank      Inbursa  \
# count        66.000000      66.000000      66.000000    66.000000
# mean     185778.403065   79772.261710  151672.437609  5993.661195
# std       28203.098747   29293.370119   28737.637611   343.038797
# min      137653.159900   38862.208430  107742.170400  5538.765900
# ...

# %%
df1.columns
# Out:
# Index(['Sistema', 'BBVA México', 'Santander', 'Banamex', 'Banorte', 'HSBC',
#        'Scotiabank', 'Inbursa', 'Banco del BajÃ­o', 'J.P. Morgan',
#        'Banco Azteca', 'Afirme', 'Bank of America', 'Banregio', 'Multiva',
#        'Invex', 'Monex', 'Banca Mifel', 'Barclays', 'Ve por MÃ¡s', 'CIBanco',
#        'Banco Base', 'Actinver', 'Compartamos', 'BansÃ­', 'Sabadell',
#        'American Express', 'Consubanco', 'ABC Capital',
#        'Inmobiliario Mexicano', 'Volkswagen Bank', 'Autofin', 'ICBC',
#        'Deutsche Bank', 'Mizuho Bank', 'Shinhan', 'Bankaool', 'Dondé Banco',
#        'Forjadores'],
#       dtype='object', name='Entidad')

# %% [markdown]
# ## Visualización de Datos: Saldo de Cartera

# %%
fig2, ax2=plt.subplots(figsize=(9,5), layout='constrained')
#style.use('ggplot')

df1['Sistema'].plot(ax=ax2, linestyle= '-', color= 'red', linewidth='2')
df1[['BBVA México','Banorte','Santander','Scotiabank','HSBC','Banamex']].plot(ax=ax2, linestyle= '--', linewidth='1.2', alpha=0.8)

ax2.set_title('Saldo de Cartera: Créditos a la Vivienda  \n Información al mes de Julio 2023',fontsize= 12, color='blue')

ax2.set_xlabel('Periodo', fontsize= 9, color='black')

ax2.tick_params(labelsize='medium', width=3)
ax2.set_ylabel('Saldo de Cartera (mmdp)', fontsize= 9, color='black')
ax2.legend(loc="upper right", fontsize=7)

ax2.grid(alpha=0.2, color ='g')

plt.yticks(fontsize=7)

plt.show()

# %%
df1.tail(5)
# Out:
# Entidad         Sistema  BBVA México    Santander      Banamex      Banorte  \
# index
# 2023-02-01  1230778.158  313912.8522  211257.1790  69626.04095  232827.8765
# 2023-03-01  1243397.406  316449.3746  212371.8437  70432.96406  235887.7557
# 2023-04-01  1250242.193  318720.6676  212584.2804  70201.22018  237944.9099
# 2023-05-01  1261467.092  320380.5519  213171.9544  70866.01756  240695.7537
# 2023-06-01  1272392.475  322650.0850  214844.6770  70771.01039  243497.5644
#
# Entidad            HSBC   Scotiabank      Inbursa  Banco del BajÃ­o  \
# index
# 2023-02-01  126932.7464  199281.5705  5911.494613       5147.519833
# 2023-03-01  129337.7897  201240.4353  5931.775500       5106.716253
# 2023-04-01  130945.8765  202733.9405  5904.410938       5085.290677
# 2023-05-01  133546.2162  204927.8045  5872.189058       4969.459426
# 2023-06-01  135755.0705  207223.5103  5837.274566       4916.565699
#
# Entidad     J.P. Morgan  ...  Inmobiliario Mexicano  Volkswagen Bank  \
# ...

# %%
df1.sort_index(ascending=True, inplace=True)

# %%
df5 = df1.copy()

# %%
for column in df5:
  df5[column]= df5[column].pct_change(periods=12)*100

# %%
df5.fillna(0, inplace=True)

# %%
df5 = df5.loc["2019":"2023"]

# %%
df5.tail(5)
# Out:
# Entidad       Sistema  BBVA México  Santander   Banamex    Banorte       HSBC  \
# index
# 2023-02-01  11.277418    10.557226   7.981645 -1.517113  14.700212  20.764864
# 2023-03-01  11.222222    10.282320   7.598110 -0.350327  15.401850  20.720830
# 2023-04-01  11.031469     9.763917   6.918058  0.793103  15.723876  20.520911
# 2023-05-01  10.941658     9.266721   6.095249  2.564711  16.151971  20.921000
# 2023-06-01  10.780234     8.684866   6.065588  3.278623  16.295200  20.742217
#
# Entidad     Scotiabank   Inbursa  Banco del BajÃ­o  J.P. Morgan  ...  \
# index                                                            ...
# 2023-02-01   14.206776  4.726646         -9.338028          0.0  ...
# 2023-03-01   13.623288  5.047553         -9.270565          0.0  ...
# 2023-04-01   13.259578  3.952139         -9.872431          0.0  ...
# 2023-05-01   12.958297  2.751459        -10.396164          0.0  ...
# 2023-06-01   12.814147  1.896450        -10.944543          0.0  ...
#
# ...

# %%
df5.max()
# Out:
# Entidad
# Sistema                    11.478666
# BBVA México                11.949360
# Santander                  15.183428
# Banamex                     4.810407
# Banorte                    16.295200
# HSBC                       35.141088
# Scotiabank                 18.087291
# Inbursa                     6.258298
# Banco del BajÃ­o            0.704374
# J.P. Morgan                 0.000000
# Banco Azteca               34.417433
# Afirme                     20.586802
# Bank of America             0.000000
# Banregio                   15.026752
# Multiva                     1.409279
# Invex                     145.872327
# Monex                    3921.873770
# Banca Mifel                33.375881
# Barclays                    0.000000
# Ve por MÃ¡s                62.569201
# CIBanco                   104.135591
# Banco Base                  0.000000
# Actinver                    0.000000
# Compartamos                 0.000000
# BansÃ­                     41.443973
# ...

# %%
df5.min()
# Out:
# Entidad
# Sistema                    9.092556
# BBVA México                7.935200
# Santander                  6.065588
# Banamex                  -11.190138
# Banorte                    5.199727
# HSBC                      20.520911
# Scotiabank                 7.468283
# Inbursa                   -8.448405
# Banco del BajÃ­o         -12.493296
# J.P. Morgan                0.000000
# Banco Azteca             -22.290885
# Afirme                     5.346693
# Bank of America            0.000000
# Banregio                   0.788248
# Multiva                  -25.595527
# Invex                    -39.892827
# Monex                    -95.983334
# Banca Mifel               -4.362140
# Barclays                   0.000000
# Ve por MÃ¡s              -16.588880
# CIBanco                  -55.836039
# Banco Base                 0.000000
# Actinver                   0.000000
# Compartamos                0.000000
# BansÃ­                   -53.618443
# Sabadell                 -28.559001
# ...

# %%
fig3, ax3=plt.subplots(figsize=(9,5), layout='constrained')

df5['Sistema'].plot(ax=ax3, linestyle= '-', color= 'red', linewidth='2')
df5[['BBVA México','Banorte','Santander','Scotiabank','HSBC','Banamex']].plot(ax=ax3, linestyle= '--', linewidth='1.2', alpha=0.8)

ax3.set_title('Saldo de Cartera: Créditos a la Vivienda  \n Información al mes de Julio 2023',fontsize= 12, color='blue')

ax3.set_xlabel('Periodo', fontsize= 9, color='black')

ax3.tick_params(labelsize='medium', width=3)
ax3.set_ylabel('Crecimiento Saldo de Cartera 12 meses (%)', fontsize= 9, color='black')
ax3.legend(loc="upper right", fontsize=7)

ax3.grid(alpha=0.2, color ='g')

plt.yticks(fontsize=7)

plt.show()

# %%
df6 = df5.iloc[-1]

# %%
df6.sort_values(ascending=False)
# Out:
# Entidad
# Invex                    44.737304
# CIBanco                  41.796129
# HSBC                     20.742217
# Banorte                  16.295200
# Banregio                 15.026752
# Afirme                   13.568280
# Scotiabank               12.814147
# Sistema                  10.780234
# BBVA México               8.684866
# Santander                 6.065588
# Banamex                   3.278623
# Inbursa                   1.896450
# Banco Azteca              1.552279
# Dondé Banco               0.000000
# Bankaool                  0.000000
# American Express          0.000000
# Shinhan                   0.000000
# Mizuho Bank               0.000000
# Deutsche Bank             0.000000
# ICBC                      0.000000
# Volkswagen Bank           0.000000
# ABC Capital               0.000000
# Consubanco                0.000000
# Forjadores                0.000000
# Compartamos               0.000000
# Actinver                  0.000000
# ...

# %%
EF1 = 'BBVA México'
EF2 = 'Banorte'
EF3 = 'Santander'
EF4 = 'Scotiabank'
EF5 = 'HSBC'
EF6 = 'Banamex'
EF7 = 'Afirme'
EF8 = 'Banregio'

# %% [markdown]
# ## Gráficas comparativas

# %%
fig4, axs = plt.subplots(nrows=3, ncols=3, figsize=(12, 7), layout='constrained')

axs[0, 0].set_title("Sistema", color="r", fontsize = 11)
axs[0, 0].plot(df5['Sistema'], color='r', )
axs[0, 0].set_xlabel("Periodo", fontsize=9)
axs[0, 0].set_ylabel("Var. Anual (%)", fontsize=9)
axs[0, 0].tick_params(labelsize=5, labelrotation= 30)

axs[0, 1].set_title(EF1, color="r", fontsize = 11)
axs[0, 1].plot(df5[EF1], color='C0')
axs[0, 1].set_xlabel("Periodo", fontsize=9)
axs[0, 1].set_ylabel("Var. Anual (%)", fontsize=9)
axs[0, 1].tick_params(labelsize=5, labelrotation= 30)

axs[0, 2].set_title(EF2, color="r", fontsize = 11)
axs[0, 2].plot(df5[EF2], color='orange')
axs[0, 2].set_xlabel("Periodo", fontsize=9)
axs[0, 2].set_ylabel("Var. Anual (%)", fontsize=9)
axs[0, 2].tick_params(labelsize=5, labelrotation= 30)

axs[1, 0].set_title(EF3, color='r', fontsize = 11)
axs[1, 0].plot(df5[EF3], color='green', linestyle="--")
axs[1, 0].set_xlabel("Periodo", fontsize=9)
axs[1, 0].set_ylabel("Var. Anual (%)", fontsize=9)
axs[1, 0].tick_params(labelsize=5, labelrotation= 30)

axs[1, 1].set_title(EF4, color="r", fontsize = 11)
axs[1, 1].plot(df5[EF4], color='cyan')
axs[1, 1].set_xlabel("Periodo", fontsize=9)
axs[1, 1].set_ylabel("Var. Anual (%)", fontsize=9)
axs[1, 1].tick_params(labelsize=5, labelrotation= 30)

axs[1, 2].set_title(EF5, color='r', fontsize = 11)
axs[1, 2].plot(df5[EF5], color='purple')
axs[1, 2].set_xlabel("Periodo", fontsize=9)
axs[1, 2].set_ylabel("Var. Anual (%)", fontsize=9)
axs[1, 2].tick_params(labelsize=5, labelrotation= 30)

axs[2, 0].set_title(EF6, color='r', fontsize = 11)
axs[2, 0].plot(df5[EF6], color='gray' )
axs[2, 0].set_xlabel("Periodo", fontsize=9)
axs[2, 0].set_ylabel("Var. Anual (%)", fontsize=9)
axs[2, 0].tick_params(labelsize=5, labelrotation= 30)

axs[2, 1].set_title(EF7, color='r', fontsize = 11)
axs[2, 1].plot(df5[EF7], color='black')
axs[2, 1].set_xlabel("Periodo", fontsize=9)
axs[2, 1].set_ylabel("Var. Anual (%)", fontsize=9)
axs[2, 1].tick_params(labelsize=5, labelrotation= 30)

axs[2, 2].set_title(EF8, color='r', fontsize = 11)
axs[2, 2].plot(df5[EF8], color='y')
axs[2, 2].set_xlabel("Periodo", fontsize=9)
axs[2, 2].set_ylabel("Var. Anual (%)", fontsize=9)
axs[2, 2].tick_params(labelsize=6, labelrotation= 30)


plt.suptitle("Crecimiento de la Cartera 12 meses", color='olivedrab', fontsize=14)
# Out:
# Text(0.5, 0.98, 'Crecimiento de la Cartera 12 meses')

# %%
from matplotlib import cm
from matplotlib import colors

cartera = [df1[EF1].iloc[-1], df1[EF2].iloc[-1], df1[EF3].iloc[-1],df1[EF4].iloc[-1],df1[EF5].iloc[-1],
           df1[EF6].iloc[-1],df1[EF7].iloc[-1],df1[EF8].iloc[-1]]
nombres = [EF1, EF2, EF3, EF4, EF5, EF6, EF7, EF8]

normdata = colors.Normalize(min(cartera), max(cartera))
colormap = cm.get_cmap("Greens")
colores =colormap(normdata(cartera))

fig5, ax5 = plt.subplots(figsize=(7, 5), layout='constrained')

plt.bar(nombres, cartera, color= colores)
plt.grid(alpha=0.2)
plt.title('Saldo de cartera \n Al mes de Julio 2023 \n Principales Entidades Financieras', color='blue', fontsize=12)
plt.show()
# Out:
# <ipython-input-83-56854602a921>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap("Greens")

# %%
df1.iloc[-1]
# Out:
# Entidad
# Sistema                  1.272392e+06
# BBVA México              3.226501e+05
# Santander                2.148447e+05
# Banamex                  7.077101e+04
# Banorte                  2.434976e+05
# HSBC                     1.357551e+05
# Scotiabank               2.072235e+05
# Inbursa                  5.837275e+03
# Banco del BajÃ­o         4.916566e+03
# J.P. Morgan              0.000000e+00
# Banco Azteca             5.001280e+02
# Afirme                   1.209705e+04
# Bank of America          0.000000e+00
# Banregio                 1.392379e+04
# Multiva                  4.942890e+02
# Invex                    5.739325e+01
# Monex                    3.392288e+01
# Banca Mifel              2.002971e+04
# Barclays                 0.000000e+00
# Ve por MÃ¡s              1.178333e+04
# CIBanco                  1.965768e+03
# Banco Base               0.000000e+00
# Actinver                 0.000000e+00
# Compartamos              0.000000e+00
# ...

# %%
# Ejercicio 2018 Base 100
B100_18 = df1.copy()

# %%
for column in B100_18:
  B100_18[column]= (B100_18[column] / B100_18[column].iloc[0])*100

# %%
B100_18.iloc[-1]
# Out:
# Entidad
# Sistema                  169.725714
# BBVA México              163.663141
# Santander                164.551407
# Banamex                   82.675066
# Banorte                  176.892099
# HSBC                     349.324127
# Scotiabank               192.332779
# Inbursa                   85.738409
# Banco del BajÃ­o          71.137208
# J.P. Morgan                     NaN
# Banco Azteca             132.327451
# Afirme                   205.288078
# Bank of America                 NaN
# Banregio                 150.374179
# Multiva                   44.100882
# Invex                    184.590288
# Monex                      5.107515
# Banca Mifel              162.636848
# Barclays                        NaN
# Ve por MÃ¡s              211.519834
# CIBanco                  226.031917
# Banco Base                      NaN
# Actinver                        NaN
# Compartamos                     NaN
# BansÃ­                    30.645957
# Sabadell                        inf
# ...

# %%
fig6, ax6=plt.subplots(figsize=(8,5), layout='constrained')

B100_18['Sistema'].plot(ax=ax6, linestyle= '--', color= 'red', linewidth='2.0')
B100_18[['BBVA México','Banorte','Santander','Scotiabank','HSBC','Banamex']].plot(ax=ax6, linestyle= '-', linewidth='1.0', alpha=0.8)
#B100_18['Autofin'].plot(ax=ax6, linestyle= '-', color= 'red', linewidth='2')

ax6.set_title('Saldo de Cartera: Créditos a la Vivienda  \n Crecimiento de Enero 2018 a Julio 2023 \n [Base 2018]',fontsize= 12, color='blue')

ax6.set_xlabel('Periodo', fontsize= 9, color='black')

ax6.tick_params(labelsize='medium', width=3)
ax6.set_ylabel('Crecimiento Saldo de Cartera (%)', fontsize= 9, color='black')
ax6.legend(loc="upper left", fontsize=9)

ax6.grid(alpha=0.1, color ='g')

plt.yticks(fontsize=7)

plt.show()

# %% [markdown]
# ## Participación de Mercado

# %%
#Market Share 2023
dfMarketShare = df1.loc["2023"]

# %%
dfMarketShare = dfMarketShare[['Sistema', 'BBVA México', 'Banorte', 'Santander', 'Scotiabank', 'HSBC', 'Banamex']]

# %%
dfMarketShare
# Out:
# Entidad         Sistema  BBVA México      Banorte    Santander   Scotiabank  \
# index
# 2023-01-01  1223348.377  311411.4758  230279.3592  210901.8148  197935.8227
# 2023-02-01  1230778.158  313912.8522  232827.8765  211257.1790  199281.5705
# 2023-03-01  1243397.406  316449.3746  235887.7557  212371.8437  201240.4353
# 2023-04-01  1250242.193  318720.6676  237944.9099  212584.2804  202733.9405
# 2023-05-01  1261467.092  320380.5519  240695.7537  213171.9544  204927.8045
# 2023-06-01  1272392.475  322650.0850  243497.5644  214844.6770  207223.5103
#
# Entidad            HSBC      Banamex
# index
# 2023-01-01  125009.0064  70017.36765
# 2023-02-01  126932.7464  69626.04095
# 2023-03-01  129337.7897  70432.96406
# 2023-04-01  130945.8765  70201.22018
# 2023-05-01  133546.2162  70866.01756
# 2023-06-01  135755.0705  70771.01039

# %%
dfSistema = dfMarketShare['Sistema']

# %%
dfSistema
# Out:
# index
# 2023-01-01    1223348.377
# 2023-02-01    1230778.158
# 2023-03-01    1243397.406
# 2023-04-01    1250242.193
# 2023-05-01    1261467.092
# 2023-06-01    1272392.475
# Name: Sistema, dtype: float64

# %%
for column in dfMarketShare:
  dfMarketShare[column]= (dfMarketShare[column] / dfSistema)*100

# %%
dfMarketShare
# Out:
# Entidad     Sistema  BBVA México    Banorte  Santander  Scotiabank       HSBC  \
# index
# 2023-01-01    100.0    25.455666  18.823694  17.239718   16.179841  10.218594
# 2023-02-01    100.0    25.505234  18.917128  17.164521   16.191510  10.313211
# 2023-03-01    100.0    25.450381  18.971228  17.079965   16.184724  10.401967
# 2023-04-01    100.0    25.492714  19.031905  17.003448   16.215573  10.473641
# 2023-05-01    100.0    25.397456  19.080621  16.898733   16.245196  10.586579
# 2023-06-01    100.0    25.357749  19.136986  16.885095   16.286131  10.669276
#
# Entidad      Banamex
# index
# 2023-01-01  5.723420
# 2023-02-01  5.657075
# 2023-03-01  5.664558
# 2023-04-01  5.615010
# 2023-05-01  5.617746
# 2023-06-01  5.562043

# %%
bk1 = 'BBVA México'
bk2 = 'Banorte'
bk3 = 'Santander'
bk4 = 'Scotiabank'
bk5 = 'HSBC'
bk6 = 'Banamex'
mercado = (dfMarketShare[bk1].iloc[-1] + dfMarketShare[bk2].iloc[-1]+ dfMarketShare[bk3].iloc[-1]+
              dfMarketShare[bk4].iloc[-1]+ dfMarketShare[bk5].iloc[-1]+ dfMarketShare[bk6].iloc[-1])
bk7  = 100 - mercado

# %%
bk7
# Out:
# 6.102720578412729

# %%
labels = bk1,bk2,bk3,bk4,bk5,bk6, 'Otras EF'
OtrasEF = bk7
sizes = [dfMarketShare[bk1].iloc[-1], dfMarketShare[bk2].iloc[-1], dfMarketShare[bk3].iloc[-1],
              dfMarketShare[bk4].iloc[-1], dfMarketShare[bk5].iloc[-1], dfMarketShare[bk6].iloc[-1],OtrasEF ]

fig7, ax7 = plt.subplots()
ax7.set_title('Participación de Mercado', color='saddlebrown')

ax7.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7e0a13db7df0>,
# ...
#  [Text(0.7690266630516956, 0.7865100072571067, 'BBVA México'),
#   Text(-0.6424325487785046, 0.8929056054645164, 'Banorte'),
#   Text(-1.0813198475044041, -0.20185982114589415, 'Santander'),
#   Text(-0.3711225418014752, -1.0355037706193118, 'Scotiabank'),
#   Text(0.5299652206900701, -0.9639174574925622, 'HSBC'),
#   Text(0.9330413208144878, -0.582609555064759, 'Banamex'),
#   Text(1.079845175313248, -0.20960533712837792, 'Otras EF')],
#  [Text(0.41946908893728846, 0.42900545850387634, '25.4%'),
#   Text(-0.3504177538791843, 0.4870394211624634, '19.1%'),
#   Text(-0.5898108259114931, -0.11010535698866952, '16.9%'),
#   Text(-0.20243047734625916, -0.5648202385196246, '16.3%'),
#   Text(0.28907193855822005, -0.5257731586323066, '10.7%'),
#   Text(0.5089316295351751, -0.31778703003532305, '5.6%'),
#   Text(0.5890064592617715, -0.11433018388820612, '6.1%')])

# %% [markdown]
# ## Gráficas por Entidad Financiera

# %%
Entidad = 'Sistema'
#'BBVA México'
#'HSBC'

# %%
fig8, (ax8, ax9, ax10) = plt.subplots(1, 3,figsize=(10, 4), layout='constrained', sharey=False)
#ax8=plt.subplots(figsize=(9,5), layout='constrained')
#style.use('ggplot')

ax8.plot(df4[Entidad], linestyle= '-', color= 'red', linewidth='2')
ax8.set_title('IMOR:   \n Información al mes de Julio 2023',fontsize= 11, color='blue')
ax8.set_xlabel('Periodo', fontsize= 8, color='black')
ax8.tick_params(labelsize='medium', width=3)
ax8.set_ylabel('IMOR (%)', fontsize= 8, color='black')
ax8.grid(alpha=0.2, color ='g')

ax9.plot(df5[Entidad], linestyle= '-', color= 'blue', linewidth='2')
ax9.set_title("Crecimiento Anual Saldo de Cartera", color="r", fontsize = 11)
ax9.set_xlabel('Periodo', fontsize= 8, color='black')
ax9.tick_params(labelsize='medium', width=3)
ax9.set_ylabel('Var. Anual (%)', fontsize= 8, color='black')
ax9.grid(alpha=0.2, color ='g')
ax9.tick_params(labelsize=6, labelrotation= 30)

ax10.plot(B100_18[Entidad], linestyle= '-', color= 'orange', linewidth='2')
ax10.set_title("Crecimiento Saldo de Cartera \n [Ene2018-Base100]", color="green", fontsize = 11)
ax10.set_xlabel('Periodo', fontsize= 8, color='black')
ax10.tick_params(labelsize='medium', width=3)
ax10.set_ylabel('Var. Anual (%)', fontsize= 8, color='black')
ax10.grid(alpha=0.2, color ='g')
ax10.tick_params(labelsize=6, labelrotation= 30)

plt.suptitle('Entidad Financiera: ' + str(Entidad) , color='olivedrab', fontsize=14, y=1.12)
# Out:
# Text(0.5, 1.12, 'Entidad Financiera: Sistema')

# %%
df5[Entidad]
# Out:
# index
# 2019-01-01     9.968866
# 2019-02-01    10.003908
# 2019-03-01    10.313068
# 2019-04-01    10.461028
# 2019-05-01    10.658448
# 2019-06-01    10.927496
# 2019-07-01    11.038723
# 2019-08-01    11.240000
# 2019-09-01    11.046333
# 2019-10-01    11.240834
# 2019-11-01    11.020311
# 2019-12-01    11.029694
# 2020-01-01    10.987430
# 2020-02-01    10.939425
# 2020-03-01    10.449259
# 2020-04-01    10.285442
# 2020-05-01     9.946441
# 2020-06-01     9.675569
# 2020-07-01     9.677949
# 2020-08-01     9.483072
# 2020-09-01     9.446066
# 2020-10-01     9.313796
# 2020-11-01     9.112119
# 2020-12-01     9.336460
# 2021-01-01     9.156166
# 2021-02-01     9.092556
# 2021-03-01     9.108386
# 2021-04-01     9.305264
# 2021-05-01     9.288797
# 2021-06-01     9.443430
# 2021-07-01     9.413531
# 2021-08-01     9.526576
# 2021-09-01     9.699032
# 2021-10-01     9.827036
# 2021-11-01     9.824629
# 2021-12-01     9.989803
# 2022-01-01    10.101386
# 2022-02-01    10.211314
# ...
